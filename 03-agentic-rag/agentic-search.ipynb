# %% [markdown]
# # Agentic search: going beyong agentic RAG

# %% [markdown]
# Think about how you search the web. You don't get pre-chunked fragments. You:
#
# - Search for something
# - Look at the snippets and titles
# - Open the most relevant articles
# - Read through them to find what you need

# %%
import minsearch

# %% [markdown]
# ## Setup data
#
# Note: we don't chunk the data.

# %%
from gitsource import GithubRepositoryDataReader
from minsearch import AppendableIndex

reader = GithubRepositoryDataReader(
    repo_owner="evidentlyai",
    repo_name="docs",
    allowed_extensions={"md", "mdx"},
)
files = reader.read()

parsed_docs = [doc.parse() for doc in files]

index = AppendableIndex(
    text_fields=["title", "description", "content"],
    keyword_fields=["filename"]
)
index.fit(parsed_docs)

# %% [markdown]
# ## Highlighting
#
# When we search, we don't want to return the entire document. That's too much context. Instead, we want snippets that help the agent decide which documents to read in full.

# %%
from minsearch import Highlighter, Tokenizer
from minsearch.tokenizer import DEFAULT_ENGLISH_STOP_WORDS

# %%
stopwords = DEFAULT_ENGLISH_STOP_WORDS | {"evidently"}

highlighter = Highlighter(
    highlight_fields=["content"],
    max_matches=3,
    snippet_size=50,
    tokenizer=Tokenizer(stemmer="snowball", stop_words=stopwords)
)

# %% [markdown]
# Key parameters:
# - highlight_fields: Which fields to extract snippets from
# - max_matches: How many snippets to show per document (3 = not too many)
# - snippet_size: How long each snippet should be (50 tokens = enough to understand relevance)
# - stop_words: Words to ignore (like "evidently" which appears everywhere)
# - stemmer: Matches word variations (use → using, etc.)

# %% [markdown]
# ## File index

# %%
file_index = {doc["filename"]: doc["content"] for doc in parsed_docs}

# %%
file_index["docs/setup/self-hosting.mdx"]
# Out:
# '<Info>\n  This page explains how to self-host the lightweight open-source platform. [Contact us](https://www.evidentlyai.com/get-demo) for Enterprise version with extra features and support. Compare [OSS vs. Enterprise/Cloud](/faq/oss_vs_cloud).\n</Info>\n\nIn addition to using Evidently Python library, you can self-host the UI Service to get a monitoring Dashboard and organize the results of your evaluations. This is optional: you can also view evaluation results in Python or export to JSON or HTML.\n\nTo get a self-hostable Dashboard, you must:\n\n- Create a Workspace (local or remote) to store your data.\n- Launch the UI service.\n\n## 1. Create a Workspace\n\n<Tip>\n  Sign up for a free [Evidently Cloud](cloud) account to get a managed version instantly.\n</Tip>\n\nOnce you [install Evidently](/docs/setup/installation), you will need to create a `workspace`. This designates a remote or local directory where you will store the evaluation results (JSON Reports called `snapshots`), traces or datasets. The UI Service will read the data from this source.\n\nAs a storage backend, Evidently supports:\n\n- a file system\n- any SQL-like database (such as SQLite or Postgres)\n- any S3-compatible storage (such as Amazon S3, GCS, or MinIO – through `fsspec`).\n\nThere are three scenarios, based on where you run the UI Service and store data.\n\n- **Local Workspace**. Both the UI Service and data storage are local.\n- **Remote Workspace**. Both the UI Service and data storage are remote.\n- **Workspace with remote data storage**. Run the UI Service and store data on different servers.\n\n### Local Workspace\n\nHere, you generate, store the snapshots and run the monitoring UI on the same machine.\n\nImports:\n\n```python\nfrom evidently.ui.workspace import Workspace\nfrom evidently.ui.workspace import WorkspaceBase\n```\n\nTo create a local Workspace and assign a name:\n\n```python\nws = Workspace.create("evidently_ui_workspace")\n```\n\nYou can pass a `path` parameter to specify the path to a local directory.\n\n### Remote Workspace\n\n<Info>\n  **Code example (Docker)**. See the [remote service example](https://github.com/evidentlyai/evidently/tree/main/examples/service).\n</Info>\n\nIn this scenario, you send the snapshots to a remote server. You must run the Monitoring UI on the same remote server. It will directly interface with the filesystem where the snapshots are stored.\n\nImports:\n\n```python\nfrom evidently.ui.remote import RemoteWorkspace\nfrom evidently.ui.workspace import Workspace\nfrom evidently.ui.workspace import WorkspaceBase\n```\n\nTo create a remote Workspace (UI should be running at this address):\n\n```python\nworkspace = RemoteWorkspace("http://localhost:8000")\n```\n\nYou can pass the following parameters:\n\n| Parameter                  | Description                                                                                  |\n| -------------------------- | -------------------------------------------------------------------------------------------- |\n| `self.base_url = base_url` | URL for the remote UI service.                                                               |\n| `self.secret = secret`     | String with secret, None by default. Use it if access to the URL is protected by a password. |\n\n### Remote snapshot storage\n\nIn the examples above, you store the snapshots and run the UI on the same server. Alternatively, you can store snapshots in a remote data store (such as an S3 bucket). The Monitoring UI service will interface with the designated data store to read the snapshot data.\n\nTo connect to data stores Evidently uses `fsspec` that allows accessing data on remote file systems via a standard Python interface.\n\nYou can verify supported data stores in the Fsspec documentation ([built-in implementations](https://filesystem-spec.readthedocs.io/en/latest/api.html#built-in-implementations) and [other implementations](https://filesystem-spec.readthedocs.io/en/latest/api.html#other-known- ...

# %% [markdown]
# ## Search tools

# %%
from typing import Any, Dict, List

class SearchTools:
    """
    Provides search and file retrieval utilities over an indexed data store.
    """
    def __init__(self, index: Any, highlighter: Any, file_index: Dict[str, str]) -> None:
        """
        Initialize the SearchTools instance.
        Args:
            index: Searchable index providing a `search` method.
            highlighter: Highlighter used to annotate search results.
            file_index (Dict[str, str]): Mapping of filenames to file contents.
        """
        self.index = index
        self.highlighter = highlighter
        self.file_index = file_index

    def search(self, query: str) -> List[Dict[str, Any]]:
        """
        Search the index for results matching a query and highlight them.
        Args:
            query (str): The search query to look up in the index.
        Returns:
            List[Dict[str, Any]]: A list of highlighted search result objects.
        """
        search_results = self.index.search(query=query, num_results=5)
        return self.highlighter.highlight(query, search_results)

    def get_file(self, filename: str) -> str:
        """
        Retrieve a file's contents by filename.
        Args:
            filename (str): The filename of the file to retrieve.
        Returns:
            str: The file contents if found, otherwise an error message.
        """
        if filename in self.file_index:
            return self.file_index[filename]
        return f"file {filename} does not exist"

# %%
search_tools = SearchTools(index, highlighter, file_index)

# %% [markdown]
# ## Agent instructions

# %%
instructions = """
You're a documentation assistant.

Answer the user question using only the documentation knowledge base.

Make 3 iterations:

1) First iteration:
   - Perform one search using the search tool to identify potentially relevant documents.
   - Explain (in 2â€“3 sentences) why this search query is appropriate for the user question.

2) Second iteration:
   - Analyze the results from the previous search.
   - Based on the filenames or documents returned, perform:
       - Up to 2 additional search queries to refine or expand coverage, and
       - One or more get_file calls to retrieve the full content of the most relevant documents.
   - For each search or get_file call, explain (in 2â€“3 sentences) why this action is necessary and how it helps answer the question.

3) Third iteration:
   - Analyze the retrieved document contents from get_file.
   - Synthesize the information from these documents into a final answer to the user.

IMPORTANT:
- At every step, explicitly explain your reasoning for each search query or file retrieval.
- Use only facts found in the documentation knowledge base.
- Do not introduce outside knowledge or assumptions.
- If the answer cannot be found in the retrieved documents, clearly inform the user.

Additional notes:
- The knowledge base is entirely about Evidently, so you do not need to include the word "evidently" in search queries.
- Prefer retrieving and analyzing full documents (via get_file) before producing the final answer.
"""

# %% [markdown]
# ## Running the Agent

# %%
from toyaikit.tools import Tools

from openai import OpenAI
from toyaikit.llm import OpenAIClient
from toyaikit.chat.runners import OpenAIResponsesRunner
from toyaikit.chat.interface import IPythonChatInterface
from toyaikit.chat.runners import DisplayingRunnerCallback

agent_tools = Tools()
agent_tools.add_tools(search_tools)

agent_tools.get_tools()

llm_client = OpenAIClient(
    model="gpt-4o-mini",
    client=OpenAI()
)

chat_interface = IPythonChatInterface()
runner_callback = DisplayingRunnerCallback(chat_interface=chat_interface)

# %%
agent = OpenAIResponsesRunner(
    tools=agent_tools,
    developer_prompt=instructions,
    chat_interface=chat_interface,
    llm_client=llm_client
)

# %%
query = "How can I create an evidently dashboard?"

# %%
result = agent.loop(
    query + " show me the code",
    callback=runner_callback
)
# Out:
# -> Response received
#             <details>
#             <summary>Function call: <tt>search({"query":"create dashboard"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"create dashboard"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>[
#   {
#     "title": "Add dashboard panels (UI)",
#     "description": "How to design your Dashboard with custom Panels.",
#     "content": {
#       "matches": [
#         "**Dashboards** let you **create** Panels to...",
#         "**Dashboards** let you **create** Panels to visualize eval...",
#         "...ject.\n\n&lt;Check&gt;\n  No-code **Dashboards** are available in the Evi..."
#       ],
#       "total_matches": 14
#     },
#     "filename": "docs/platform/dashboard_add_panels_ui.mdx"
#   },
#   {
#     "title": "Add dashboard panels (API)",
#     "description": "How to design your Dashboard with custom Panels.",
#     "content": {
#       "matches": [
#         "...oard_add_panels_ui).\n\n## **Dashboard** Management\n\n&lt;Check&gt;\n  **Dashboards**...",
#         "...rd Management\n\n&lt;Check&gt;\n  **Dashboards** as code are available in...",
#         "...(/docs/setup/cloud) and [**create** a Project](/docs/platfor..."
#       ],
#       "total_matches": 32
#     },
#     "filename": "docs/platform/dashboard_add_panels.mdx"
#   },
#   {
#     "title": "Custom Metric",
#     "description": "How to create a custom dataset or column-level Metric.",
#     "content": {
#       "matches": [
#         "...e a built-in template to **create** a custom [LLM-based eval...",
#         "...sualize over time on the **Dashboard**.\n\n## Example implementat...",
#         "... Report as usual.\n\nLet\u2019s **create** a sample toy dataset:\n\n`..."
#       ],
#       "total_matches": 3
#     },
#     "filename": "metrics/customize_metric.mdx"
#   },
#   {
#     "title": "Dashboard panel types [Legacy]",
#     "description": "Overview of the available monitoring Panels.",
#     "content": {
#       "matches": [
#         "...ounter on the Monitoring **Dashboard**.\u00a0\n\n* You can add multipl...",
#         "...es in time.\n\n![](/images/**dashboard**/metric_panels.png)\n\n**Pa...",
#         "... text alone. Perfect for **dashboard** titles.\n\n&lt;Frame&gt;\n  &lt;img ..."
#       ],
#       "total_matches": 68
#     },
#     "filename": "docs/platform/dashboard_panel_types.mdx"
#   },
#   {
#     "title": "Overview",
#     "description": "Introduction to Dashboard.",
#     "content": {
#       "matches": [
#         "&lt;Check&gt;\n  **Dashboard** is available in **Eviden...",
#         "....\n&lt;/Check&gt;\n\n## What is a **Dashboard**?\n\nA **Dashboard** provides a...",
#         "... What is a **Dashboard**?\n\nA **Dashboard** provides a clear view of..."
#       ],
#       "total_matches": 18
#     },
#     "filename": "docs/platform/dashboard_overview.mdx"
#   }
# ]</pre>
#             </div>
#
#             </details>
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>The search for &quot;create dashboard&quot; returned several documents that address how to create dashboards, both via the UI and API. This query is appropriate because it directly seeks the information needed to create a dashboard, focusing on the methodologies available within the Evidently platform.</p>
# <h3>Next Steps:</h3>
# <p>I will now refine the search to obtain specific code examples from the relevant documents, particularly focusing on creating panels and dashboards via the API, which should include code snippets. I’ll retrieve the full content of the most relevant documents on dashboard creation.</p>
# <p>I will focus on the following documents:</p>
# <ol>
# <li>&quot;Add dashboard panels (API)&quot;</li>
# <li>&quot;Add dashboard panels (UI)&quot;</li>
# </ol>
# <p>These documents appear directly related to both code implementation and the interface for creating dashboards.</p>
# <p>Let's proceed with actions to get these documents.</p>
# </div>
#             </div>
#             <details>
#             <summary>Function call: <tt>get_file({"filename":"docs/platform/dashboard_add_panels...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"filename":"docs/platform/dashboard_add_panels.mdx"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>"You can add Panels in the user interface or using Python API. This pages describes the Python API. Check how to [add panels in the UI](dashboard_add_panels_ui).\n\n## Dashboard Management\n\n&lt;Check&gt;\n  Dashboards as code are available in Evidently OSS, Cloud, Enterprise.\n&lt;/Check&gt;\n\n&lt;Tip&gt;\n  You must first connect to [Evidently Cloud](/docs/setup/cloud) and [create a Project](/docs/platform/projects_manage).\n&lt;/Tip&gt;\n\n**Adding Tabs**. To add a new Tab:\n\n```python\nproject.dashboard.add_tab(\"Another Tab\")\n```\n\nYou can also create a new Tab while adding a Panel as shown below. If the destination Tab doesn't exist, it will be created. If it does, the Panel will be added below existing ones in that Tab.\n\n**Deleting Tabs**. To delete a Tab:\n\n```python\nproject.dashboard.delete_tab(\"Another Tab\")\n```\n\n**Deleting Panels**. To delete a specific Panel:\n\n```python\nproject.dashboard.delete_panel(\"Dashboard title\", \"My new tab\")\n```\n\n(First list the Panel name, then the Tab name).\n\n**[DANGER]. Delete Dashboard**. To delete all Tabs and Panels on the Dashboard:\n\n```python\nproject.dashboard.clear_dashboard()\n```\n\nNote: This does **not** delete the underlying Reports or dataset; it only clears the Panels.\n\n## Adding Panels\n\nImports:\n\n```\nfrom evidently.sdk.models import PanelMetric\nfrom evidently.sdk.panels import DashboardPanelPlot\n```\n\nYou can add multiple Panels at once: they will appear in the listed order.\n\n### Text\n\nText-only panels are perfect for titles.\n\n**Add a text panel**. Add a new text panel to the specified Tab.\n\n```python\nproject.dashboard.add_panel(\n    DashboardPanelPlot(\n        title=\"Dashboard title\",\n        size=\"full\", \n        values=[], #leave empty\n        plot_params={\"plot_type\": \"text\"},\n    ),\n    tab=\"My new tab\", #will create a Tab if there is no Tab with this name\n)\n```\n\n### Counters\n\nCounter panels show a value with optional supporting text.\n\n&lt;CardGroup cols={2}&gt;\n  &lt;Card title=\"Text counter\" img=\"/images/dashboard/panel_counter_example-min.png\"&gt;\n    Shows the specified value(s) and optional text.\n  &lt;/Card&gt;\n  &lt;Card title=\"Pie chart\" img=\"/images/dashboard/panel_pie_chart.png\"&gt;\n    Shows the specified value(s) in a pie chart.\n  &lt;/Card&gt;\n&lt;/CardGroup&gt;\n\n**Add Counters**. To add panels for the `RowCount` metric with different aggregations:\n\n```python\n# Sum\nproject.dashboard.add_panel(\n    DashboardPanelPlot(\n        title=\"Row count\",\n        subtitle=\"Total number of evaluations over time.\",\n        size=\"half\",\n        values=[PanelMetric(legend=\"Row count\", metric=\"RowCount\")],\n        plot_params={\"plot_type\": \"counter\", \"aggregation\": \"sum\"},\n    ),\n    tab=\"My tab\",\n)\n\n# Average\nproject.dashboard.add_panel(\n    DashboardPanelPlot(\n        title=\"Row count\",\n        subtitle=\"Average number of evaluations per Report.\",\n        size=\"half\",\n        values=[PanelMetric(legend=\"Row count\", metric=\"RowCount\")],\n        plot_params={\"plot_type\": \"counter\", \"aggregation\": \"avg\"},\n    ),\n    tab=\"My tab\",\n)\n\n# Last\nproject.dashboard.add_panel(\n    DashboardPanelPlot(\n        title=\"Row count\",\n        subtitle=\"Latest number of evaluations.\",\n        size=\"half\",\n        values=[PanelMetric(legend=\"Row count\", metric=\"RowCount\")],\n        plot_params={\"plot_type\": \"counter\", \"aggregation\": \"last\"},\n    ),\n    tab=\"My tab\",\n)\n```\n\n**Add pie charts**. You can use the same aggregation params (`sum`, `last`, `avg`).\n\n```python\nproject.dashboard.add_panel(\n    DashboardPanelPlot(\n        title=\"Row count\",\n        subtitle=\"Total number of evaluations over time.\",\n        size=\"half\",\n        values=[PanelMetric(legend=\"Row count\", metric=\"RowCount\")],\n        plot_params={\"plot_type\": \"pie\", \"aggregation\": \"sum\"},\n    ...
#             <details>
#             <summary>Function call: <tt>get_file({"filename":"docs/platform/dashboard_add_panels...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"filename":"docs/platform/dashboard_add_panels_ui.mdx"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>"Dashboards let you create Panels to visualize evaluation results over time. Note that to be able to populate the panels, you must first add Reports with evaluation results to the Project.\n\n&lt;Check&gt;\n  No-code Dashboards are available in the Evidently Cloud and Enterprise.\n&lt;/Check&gt;\n\n## Adding Tabs\n\nBy default, new Panels appear on a single Dashboard. You can add multiple Tabs to organize them.\n\n**To add a Tab**:\n\n- Enter \"Edit\" mode on the Dashboard (top right corner).\n- Click the plus sign with \"add Tab\" on the left.\n- To create a custom Tab, select \"empty\" and enter a name.\n\nTo simplify setup, you can start with pre-built Tabs. These are dashboard templates with preset Panel combinations:\n\n![Add Dashboard Tab](/images/dashboard/add_dashboard_tab_v2.gif)\n\n**Pre-built Tabs** rely on having related Metrics (or Presets that include the specific Metrics) within the Project. If the necessary data is not available, the Panels will appear empty until you add Reports that contain those Metrics.\n\nAvailable Tabs:\n\n| Template    | Description                                                                                                                    | Data source                                                                 |\n| ----------- | ------------------------------------------------------------------------------------------------------------------------------ | --------------------------------------------------------------------------- |\n| **Columns** | Shows the results of text evaluations over time OR plots column distributions over time for categorical and numerical columns. | `TextEvals()`, `DataSumaryPreset()`or`ValueStats()` for individual columns. |\n\n**To delete a Tab**: enter the \"Edit\" mode again, choose \"edit Tabs\" sign next to the Tab names on the left, and choose which one to delete.\n\n## Adding Panels\n\nYou can add any number of Panels to your Dashboard, including text panels, counters, pie charts, line plots, and bar plots (grouped and stacked). When you create a Panel, you pull the corresponding value from multiple Reports and show it over time or using the specified aggregation (sum, average, last).\n\n&lt;Info&gt;\n  Check the preview and description of each Panel here: [How to add panels via Python API](dashboard_add_panels).\n&lt;/Info&gt;\n\n**How to add a Panel:**\n\n- Enter \"Edit\" mode on the Dashboard (top right corner).\n- Click on the \"Add Panel\" button next to it.\n- Follow the prompts to configure the panel.\n- Use the preview to review your setup.\n- Click \"Save\" and select the Tab where you want to add the Panel.\n\nHere is an example of the panel configuration view:\n\n![](/images/dashboard/add_panel_ui.png)\n\n- **Select Metrics**. To point to a specific Metric, you must choose the Metric name that matches the name of the Evidently Metric logged inside the Reports in the given Project.\n- **Filter by Tag.** By default, the metrics will be parsed from all Reports in the Project. Use the \"From\" field to filter by Tags. (You must first attach these tags to the corresponding Reports).\n- **Filter by Metric label.** If you have a single Metric of that type in the Project (like `RowCount`), it may be enough to just specify the metric name. However, if you have multiple instances of the same metric - as is often the case for column-level Metrics like `UniqueValueCount` - you need to specify additional parameters. Use the \"Where\" selector to specify further keys like:\n  - **Column**: Use this to select the name of the column or descriptor.\n  - **Value type**: Choose whether to plot value or count for metrics that return both.\n\n  You can see all keys available for a given Metric in the dropdown menu. You can add multiple keys, depending on the metric type, like metric-specific parameters.\n- **Set Legend**. You can use the \"Label\" field to modify what appears on the legend.\n- **Set Panel Type**. You can also speci ...
#             </div>
#
#             </details>
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><h3>Final Analysis and Synthesis</h3>
# <p>The documents retrieved provide comprehensive instructions on how to create dashboards and add panels using both the UI and the Python API.</p>
# <h4>Code Snippet for Creating a Dashboard</h4>
# <p>Here’s a concise example focusing on how to add panels programmatically using Python:</p>
# <pre><code class="language-python">from evidently.sdk.models import PanelMetric
# from evidently.sdk.panels import DashboardPanelPlot
#
# # Add a new tab to the dashboard
# project.dashboard.add_tab(&quot;My Tab&quot;)
#
# # Add a text panel
# project.dashboard.add_panel(
#     DashboardPanelPlot(
#         title=&quot;Dashboard Title&quot;,
#         size=&quot;full&quot;,
#         values=[],  # Leave empty for a text panel
#         plot_params={&quot;plot_type&quot;: &quot;text&quot;},
#     ),
#     tab=&quot;My Tab&quot;,  # Specify the tab name
# )
#
# # Add a counter panel
# project.dashboard.add_panel(
#     DashboardPanelPlot(
#         title=&quot;Row Count&quot;,
#         subtitle=&quot;Total number of evaluations over time.&quot;,
#         size=&quot;half&quot;,
#         values=[PanelMetric(legend=&quot;Row count&quot;, metric=&quot;RowCount&quot;)],
#         plot_params={&quot;plot_type&quot;: &quot;counter&quot;, &quot;aggregation&quot;: &quot;sum&quot;},
#     ),
#     tab=&quot;My Tab&quot;,
# )
# </code></pre>
# <h3>Summary</h3>
# <ul>
# <li>You can create a new tab in the dashboard using <code>project.dashboard.add_tab()</code>.</li>
# <li>Use <code>DashboardPanelPlot</code> to configure your panel’s settings—like its type, size, and metrics.</li>
# <li>The example above demonstrates adding a text panel for titles and a counter panel for displaying metrics.</li>
# </ul>
# <p>Feel free to adapt the examples above to your specific needs regarding panel types and metrics!</p>
# </div>
#             </div>
